# %% [markdown]
# # Demo notebook
#
# Anton Antonov
# December 2025

# %% [markdown]
# ---
#
# ## Introduction

# %% [markdown]
# This is a small demo Jupyter notebook.

# %% [markdown]
# ----
#
# ## Content

# %% [markdown]
# Here is a list of steps:
#
# - Make a prefix tree (trie) with frequencies using word splitting over `@words2`
# - Merge the trie with the another trie made over `@words3`
# - Convert the node frequencies into probabilities
# - Shrink the trie (i.e. find the "prefixes")
# - Show the tree-form of the trie

# %%
use ML::TriesWithFrequencies;

my @words2 = <bar barman bask bell belly>;
my @words3 = <call car cast>;

trie-create-by-split(@words2)==>
trie-merge(trie-create-by-split(@words3))==>
trie-node-probabilities==>
trie-shrink==>
trie-say
# Out:
# TRIEROOT => 1
# ├─b => 0.625
# │ ├─a => 0.6
# │ │ ├─r => 0.6666666666666666
# │ │ │ └─man => 0.5
# │ │ └─sk => 0.3333333333333333
# │ └─ell => 0.4
# │   └─y => 0.5
# └─ca => 0.375
#   ├─ll => 0.3333333333333333
#   ├─r => 0.3333333333333333
#   └─st => 0.3333333333333333

# %% [markdown]
# Make a random graph and plot it:

# %%
#% html
use Graph;
use Graph::Classes;

Graph::Random.new(8, 9).dot(engine => 'neato'):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="312pt" height="224pt"
#  viewBox="0.00 0.00 312.00 224.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 219.98)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-219.98 307.89,-219.98 307.89,4 -4,4"/>
# <!-- 1 -->
# <g id="node1" class="node">
# <title>1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-114.74" rx="10.8" ry="10.8"/>
# <text xml:space="preserve" text-anchor="middle" x="10.8" y="-110.47" font-family="Times,serif" font-size="12.00" fill="White">1</text>
# </g>
# <!-- 4 -->
# <g id="node4" class="node">
# <title>4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="83.58" cy="-102.93" rx="10.8" ry="10.8"/>
# <text xml:space="preserve" text-anchor="middle" x="83.58" y="-98.66" font-family="Times,serif" font-size="12.00" fill="White">4</text>
# </g>
# <!-- 1&#45;&#45;4 -->
# <g id="edge6" class="edge">
# <title>1&#45;&#45;4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M21.85,-112.95C35.69,-110.7 59.23,-106.88 72.9,-104.67"/>
# </g>
# <!-- 2 -->
# <g id="node2" class="node">
# <title>2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="159.47" cy="-87.41" rx="10.8" ry="10.8"/>
# <text xml:space="preserve" text-anchor="middle" x="159.47" y="-83.14" font-family="Times,serif" font-size="12.00" fill="White">2</text>
# </g>
# <!-- 3 -->
# <g id="node3" class="node">
# <title>3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="171.84" cy="-10.8" rx="10.8" ry="10.8"/>
# <text xml:space="preserve" text-anchor="middle" x="171.84" y="-6.52" font-family="Times,serif" font-size="12.00" fill="White">3</text>
# </g>
# <!-- 2&#45;&#45;3 -->
# <g id="edge7" class="edge">
# <title>2&#45;&#45;3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M161.24,-76.44C163.59,-61.87 167.72,-36.31 170.07,-21.76"/>
# </g>
# <!-- 2&#45;&#45;4 -->
# <g id="edge8" class="edge">
# <title>2&#45;&#45;4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M148.6,-89.64C134.17,-92.59 108.85,-97.77 94.43,-100.72"/>
# </g>
# <!-- 6 -->
# <g id="node6" class="node">
# <title>6</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.88" cy="-61.91" rx="10.8" ry="10.8"/>
# <text xml:space="preserve" text-anchor="middle" x="226.88" y="-57.63" font-family="Times,serif" font-size="12.00" fill="White">6</text>
# </g>
# <!-- 2&#45;&#45;6 -->
# <g id="edge4" class="edge">
# <title>2&#45;&#45;6</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M170,-83.43C182.74,-78.61 204.03,-70.55 216.64,-65.78"/>
# </g>
# <!-- 7 -->
# <g id="node7" class="node">
# <title>7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="218.46" cy="-137.45" rx="10.8" ry="10.8"/>
# <text xml:space="preserve" text-anchor="middle" x="218.46" y="-133.17" font-family="Times,serif" font-size="12.00" fill="White">7</text>
# </g>
# <!-- 2&#45;&#45;7 -->
# <g id="edge9" class="edge">
# <title>2&#45;&#45;7</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M167.92,-94.58C179.13,-104.09 198.82,-120.79 210.02,-130.29"/>
# </g>
# <!-- 3&#45;&#45;6 -->
# <g id="edge3" class="edge">
# <title>3&#45;&#45;6</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M179.96,-18.34C190.36,-28 208.3,-44.66 218.72,-54.34"/>
# </g>
# <!-- 5 -->
# <g id="node5" class="node">
# <title>5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="253.08" cy="-205.18" rx="10.8" ry="10.8"/>
# <text xml:space="preserve" text-anchor="middle" x="253.08" y="-200.9" font-family="Times,serif" font-size="12.00" fill="White">5</text>
# </g>
# <!-- 5&#45;&#45;7 -->
# <g id="edge2" class="edge">
# <title>5&#45;&#45;7</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M247.97,-195.18C241.43,-182.38 230.14,-160.31 223.59,-147.48"/>
# </g>
# <!-- 6&#45;&#45;7 -->
# <g id="edge5" class="edge">
# <title>6&#45;&#45;7</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M225.63,-73.05C224.04,-87.34 221.3,-111.95 219.7,-126.26"/>
# </g>
# <!-- 8 -->
# <g id="node8" class="node">
# <title>8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="293.09" cy="-21.82" rx="10.8" ry="10.8"/>
# <text xml:space="preserve" text-anchor="middle" x="293.09" y="-17.55" font-family="Times,serif" font-size="12.00" fill="White">8</text>
# </g>
# <!-- 6&#45;&#45;8 -->
# <g id="edge1" class="edge">
# <title>6&#45;&#45;8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M236.36,-56.17C248.95,-48.55 271.05,-35.17 283.62,-27.56"/>
# </g>
# </g>
# </svg>
